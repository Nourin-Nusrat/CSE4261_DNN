# %% [markdown]
# <a href="https://colab.research.google.com/github/Nourin-Nusrat/CSE4261_DNN/blob/main/Assignment8/DNN_Assignment8_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow-datasets

# %%
# !pip install contextlib2 lxml pillow matplotlib Cython

# %%
# !rm -rf ~/tensorflow_datasets/oxford_iiit_pet

# %%
# !pip install keras-cv

# %%
import keras
from keras import layers
from keras import ops

import os
import numpy as np
from glob import glob
import cv2
from scipy.io import loadmat
import matplotlib.pyplot as plt

# For data preprocessing
from tensorflow import image as tf_image
from tensorflow import data as tf_data
from tensorflow import io as tf_io

import keras_cv
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, backend

os.environ["KERAS_BACKEND"] = "tensorflow"
import keras_cv
import tensorflow as tf
import keras
from keras import layers, ops

# %%
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz  -P /content --no-check-certificate
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz  -P /content --no-check-certificate
# %cd /content

# !tar -C /content -xvf /content/images.tar.gz
# !tar -C /content -xvf /content/annotations.tar.gz

# %%
input_dir = "images/"
target_dir = "annotations/trimaps/"
img_size = (160, 160)
num_classes = 3
batch_size = 32

input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".jpg")
    ]
)
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

print("Number of samples:", len(input_img_paths))

for input_path, target_path in zip(input_img_paths[:10], target_img_paths[:10]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 7390
# images/Abyssinian_1.jpg | annotations/trimaps/Abyssinian_1.png
# images/Abyssinian_10.jpg | annotations/trimaps/Abyssinian_10.png
# images/Abyssinian_100.jpg | annotations/trimaps/Abyssinian_100.png
# images/Abyssinian_101.jpg | annotations/trimaps/Abyssinian_101.png
# images/Abyssinian_102.jpg | annotations/trimaps/Abyssinian_102.png
# images/Abyssinian_103.jpg | annotations/trimaps/Abyssinian_103.png
# images/Abyssinian_104.jpg | annotations/trimaps/Abyssinian_104.png
# images/Abyssinian_105.jpg | annotations/trimaps/Abyssinian_105.png
# images/Abyssinian_106.jpg | annotations/trimaps/Abyssinian_106.png
# images/Abyssinian_107.jpg | annotations/trimaps/Abyssinian_107.png

# %%
from IPython.display import Image, display
from keras.utils import load_img
from PIL import ImageOps
display(Image(filename=input_img_paths[9]))
img = ImageOps.autocontrast(load_img(target_img_paths[9]))
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x448>

# %%
import keras
import numpy as np
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import io as tf_io


def get_dataset(
    batch_size,
    img_size,
    input_img_paths,
    target_img_paths,
    max_dataset_len=None,
):

    def load_img_masks(input_img_path, target_img_path):
        input_img = tf_io.read_file(input_img_path)
        input_img = tf_io.decode_png(input_img, channels=3)
        input_img = tf_image.resize(input_img, img_size)
        input_img = tf_image.convert_image_dtype(input_img, "float32")

        target_img = tf_io.read_file(target_img_path)
        target_img = tf_io.decode_png(target_img, channels=1)
        target_img = tf_image.resize(target_img, img_size, method="nearest")
        target_img = tf_image.convert_image_dtype(target_img, "uint8")
        target_img -= 1
        return input_img, target_img

    # For faster debugging, limit the size of data
    if max_dataset_len:
        input_img_paths = input_img_paths[:max_dataset_len]
        target_img_paths = target_img_paths[:max_dataset_len]
    dataset = tf_data.Dataset.from_tensor_slices((input_img_paths, target_img_paths))
    dataset = dataset.map(load_img_masks, num_parallel_calls=tf_data.AUTOTUNE)
    return dataset.batch(batch_size)

# %% [markdown]
# #Test code

# %%
import os

input_dir = "images/"
target_dir = "annotations/trimaps/"
img_size = (160, 160)
num_classes = 3
batch_size = 32

input_img_paths = sorted(
    [
        os.path.join(input_dir, fname)
        for fname in os.listdir(input_dir)
        if fname.endswith(".jpg")
    ]
)
target_img_paths = sorted(
    [
        os.path.join(target_dir, fname)
        for fname in os.listdir(target_dir)
        if fname.endswith(".png") and not fname.startswith(".")
    ]
)

print("Number of samples:", len(input_img_paths))

for input_path, target_path in zip(input_img_paths[:10], target_img_paths[:10]):
    print(input_path, "|", target_path)

import keras
import numpy as np
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import io as tf_io


def get_dataset(
    batch_size,
    img_size,
    input_img_paths,
    target_img_paths,
    max_dataset_len=None,
):
    """Returns a TF Dataset."""

    def load_img_masks(input_img_path, target_img_path):
        input_img = tf_io.read_file(input_img_path)
        input_img = tf_io.decode_png(input_img, channels=3)
        input_img = tf_image.resize(input_img, img_size)
        input_img = tf_image.convert_image_dtype(input_img, "float32")

        target_img = tf_io.read_file(target_img_path)
        target_img = tf_io.decode_png(target_img, channels=1)
        target_img = tf_image.resize(target_img, img_size, method="nearest")
        target_img = tf_image.convert_image_dtype(target_img, "uint8")
        target_img -= 1
        return input_img, target_img
    if max_dataset_len:
        input_img_paths = input_img_paths[:max_dataset_len]
        target_img_paths = target_img_paths[:max_dataset_len]
    dataset = tf_data.Dataset.from_tensor_slices((input_img_paths, target_img_paths))
    dataset = dataset.map(load_img_masks, num_parallel_calls=tf_data.AUTOTUNE)
    return dataset.batch(batch_size)
import random
val_samples = 1000
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

train_dataset = get_dataset(
    batch_size,
    img_size,
    train_input_img_paths,
    train_target_img_paths,
    max_dataset_len=1000,
)
valid_dataset = get_dataset(
    batch_size, img_size, val_input_img_paths, val_target_img_paths
)


from IPython.display import Image, display
from keras.utils import load_img
from PIL import ImageOps

display(Image(filename=input_img_paths[9]))
img = ImageOps.autocontrast(load_img(target_img_paths[9]))
display(img)
# Out:
# Number of samples: 7390
# images/Abyssinian_1.jpg | annotations/trimaps/Abyssinian_1.png
# images/Abyssinian_10.jpg | annotations/trimaps/Abyssinian_10.png
# images/Abyssinian_100.jpg | annotations/trimaps/Abyssinian_100.png
# images/Abyssinian_101.jpg | annotations/trimaps/Abyssinian_101.png
# images/Abyssinian_102.jpg | annotations/trimaps/Abyssinian_102.png
# images/Abyssinian_103.jpg | annotations/trimaps/Abyssinian_103.png
# images/Abyssinian_104.jpg | annotations/trimaps/Abyssinian_104.png
# images/Abyssinian_105.jpg | annotations/trimaps/Abyssinian_105.png
# images/Abyssinian_106.jpg | annotations/trimaps/Abyssinian_106.png
# images/Abyssinian_107.jpg | annotations/trimaps/Abyssinian_107.png
# <PIL.Image.Image image mode=RGB size=500x333>

# %%
from keras import layers


def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Build model
model = get_model(img_size, num_classes)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 160, 160,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 80, 80,    │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 80, 80,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 80, 80,    │          0 │ activation[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 80, 80,    │      2,400 │ activation_1[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 80, 80,    │      4,736 │ activation_2[0][… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 40, 40,    │      2,112 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 40, 40,    │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 40, 40,    │          0 │ add[0][0]         │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 40, 40,    │      8,896 │ activation_3[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 40, 40,    │     17,664 │ activation_4[0][… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 20, 20,    │      8,320 │ add[0][0]         │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 20, 20,    │          0 │ max_pooling2d_1[… │
# │                     │ 128)              │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 20, 20,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 20, 20,    │     34,176 │ activation_5[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 20, 20,    │     68,096 │ activation_6[0][… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 10, 10,    │     33,024 │ add_1[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 10, 10,    │          0 │ max_pooling2d_2[… │
# │                     │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 10, 10,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 10, 10,    │    590,080 │ activation_7[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10, 10,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 10, 10,    │    590,080 │ activation_8[0][… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 10,    │      1,024 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 20, 20,    │          0 │ add_2[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 20,    │     65,792 │ up_sampling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 20, 20,    │          0 │ up_sampling2d[0]… │
# │                     │ 256)              │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 20, 20,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 20, 20,    │    295,040 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 20, 20,    │    147,584 │ activation_10[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 40, 40,    │          0 │ add_3[0][0]       │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 40, 40,    │     32,896 │ up_sampling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 40, 40,    │          0 │ up_sampling2d_2[… │
# │                     │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 40, 40,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 40, 40,    │     73,792 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 40, 40,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 40, 40,    │     36,928 │ activation_12[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 40,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 80, 80,    │          0 │ add_4[0][0]       │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 80, 80,    │      8,256 │ up_sampling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 80, 80,    │          0 │ up_sampling2d_4[… │
# │                     │ 64)               │            │ conv2d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 80, 80,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 80, 80,    │     18,464 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 80, 80,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 80, 80,    │      9,248 │ activation_14[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 80,    │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 160, 160,  │          0 │ add_5[0][0]       │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 160, 160,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 160, 160,  │      2,080 │ up_sampling2d_7[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 160, 160,  │          0 │ up_sampling2d_6[… │
# │                     │ 32)               │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 160, 160,  │        867 │ add_6[0][0]       │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,058,979 (7.85 MB)
#  Trainable params: 2,055,203 (7.84 MB)
#  Non-trainable params: 3,776 (14.75 KB)

# %%
import random

# Split our img paths into a training and a validation set
val_samples = 1000
random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_img_paths)
train_input_img_paths = input_img_paths[:-val_samples]
train_target_img_paths = target_img_paths[:-val_samples]
val_input_img_paths = input_img_paths[-val_samples:]
val_target_img_paths = target_img_paths[-val_samples:]

# Instantiate dataset for each split
# Limit input files in `max_dataset_len` for faster epoch training time.
# Remove the `max_dataset_len` arg when running with full dataset.
train_dataset = get_dataset(
    batch_size,
    img_size,
    train_input_img_paths,
    train_target_img_paths,
    max_dataset_len=1000,
)
valid_dataset = get_dataset(
    batch_size, img_size, val_input_img_paths, val_target_img_paths
)

# %%
import tensorflow as tf

NUM_CLASSES = 3
model.compile(optimizer=keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy",metrics=["accuracy",keras.metrics.MeanIoU(num_classes=NUM_CLASSES, sparse_y_pred=False),],)

callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.keras", save_best_only=True)
]
epochs = 50
model.fit(
    train_dataset,
    epochs=epochs,
    validation_data=valid_dataset,
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Epoch 1/50
# 32/32 - 68s - 2s/step - accuracy: 0.6248 - loss: 1.4017 - mean_io_u: 0.3555 - val_accuracy: 0.5428 - val_loss: 1.0777 - val_mean_io_u: 0.2476
# Epoch 2/50
# 32/32 - 35s - 1s/step - accuracy: 0.6879 - loss: 0.8793 - mean_io_u: 0.4117 - val_accuracy: 0.5839 - val_loss: 1.0829 - val_mean_io_u: 0.1989
# Epoch 3/50
# 32/32 - 6s - 193ms/step - accuracy: 0.7122 - loss: 0.7662 - mean_io_u: 0.4344 - val_accuracy: 0.5891 - val_loss: 1.3081 - val_mean_io_u: 0.1966
# Epoch 4/50
# 32/32 - 10s - 320ms/step - accuracy: 0.7296 - loss: 0.7033 - mean_io_u: 0.4524 - val_accuracy: 0.5896 - val_loss: 1.5983 - val_mean_io_u: 0.1966
# Epoch 5/50
# 32/32 - 7s - 218ms/step - accuracy: 0.7437 - loss: 0.6589 - mean_io_u: 0.4684 - val_accuracy: 0.5897 - val_loss: 1.9019 - val_mean_io_u: 0.1966
# Epoch 6/50
# 32/32 - 11s - 331ms/step - accuracy: 0.7562 - loss: 0.6231 - mean_io_u: 0.4835 - val_accuracy: 0.5897 - val_loss: 2.2062 - val_mean_io_u: 0.1966
# Epoch 7/50
# 32/32 - 9s - 285ms/step - accuracy: 0.7679 - loss: 0.5916 - mean_io_u: 0.4983 - val_accuracy: 0.5897 - val_loss: 2.5184 - val_mean_io_u: 0.1966
# Epoch 8/50
# 32/32 - 7s - 214ms/step - accuracy: 0.7791 - loss: 0.5623 - mean_io_u: 0.5133 - val_accuracy: 0.5897 - val_loss: 2.8382 - val_mean_io_u: 0.1966
# Epoch 9/50
# 32/32 - 6s - 200ms/step - accuracy: 0.7905 - loss: 0.5334 - mean_io_u: 0.5290 - val_accuracy: 0.5897 - val_loss: 3.1792 - val_mean_io_u: 0.1966
# Epoch 10/50
# 32/32 - 10s - 317ms/step - accuracy: 0.8020 - loss: 0.5043 - mean_io_u: 0.5453 - val_accuracy: 0.5897 - val_loss: 3.5252 - val_mean_io_u: 0.1966
# Epoch 11/50
# 32/32 - 10s - 320ms/step - accuracy: 0.8137 - loss: 0.4744 - mean_io_u: 0.5625 - val_accuracy: 0.5897 - val_loss: 3.9035 - val_mean_io_u: 0.1966
# Epoch 12/50
# 32/32 - 7s - 231ms/step - accuracy: 0.8256 - loss: 0.4441 - mean_io_u: 0.5806 - val_accuracy: 0.5897 - val_loss: 4.2692 - val_mean_io_u: 0.1966
# Epoch 13/50
# 32/32 - 6s - 197ms/step - accuracy: 0.8371 - loss: 0.4145 - mean_io_u: 0.5987 - val_accuracy: 0.5897 - val_loss: 4.5311 - val_mean_io_u: 0.1966
# Epoch 14/50
# 32/32 - 7s - 218ms/step - accuracy: 0.8473 - loss: 0.3874 - mean_io_u: 0.6156 - val_accuracy: 0.5897 - val_loss: 4.6439 - val_mean_io_u: 0.1966
# Epoch 15/50
# 32/32 - 6s - 194ms/step - accuracy: 0.8545 - loss: 0.3676 - mean_io_u: 0.6286 - val_accuracy: 0.5897 - val_loss: 4.4748 - val_mean_io_u: 0.1966
# Epoch 16/50
# 32/32 - 10s - 320ms/step - accuracy: 0.8520 - loss: 0.3750 - mean_io_u: 0.6267 - val_accuracy: 0.5897 - val_loss: 3.4463 - val_mean_io_u: 0.1966
# Epoch 17/50
# 32/32 - 11s - 330ms/step - accuracy: 0.8445 - loss: 0.3962 - mean_io_u: 0.6145 - val_accuracy: 0.5903 - val_loss: 2.6770 - val_mean_io_u: 0.1985
# Epoch 18/50
# 32/32 - 10s - 327ms/step - accuracy: 0.8459 - loss: 0.3925 - mean_io_u: 0.6174 - val_accuracy: 0.6074 - val_loss: 1.5978 - val_mean_io_u: 0.2311
# Epoch 19/50
# 32/32 - 7s - 207ms/step - accuracy: 0.8369 - loss: 0.4202 - mean_io_u: 0.6051 - val_accuracy: 0.6721 - val_loss: 0.9988 - val_mean_io_u: 0.3478
# Epoch 20/50
# 32/32 - 7s - 223ms/step - accuracy: 0.8301 - loss: 0.4325 - mean_io_u: 0.5956 - val_accuracy: 0.7102 - val_loss: 0.7581 - val_mean_io_u: 0.4252
# Epoch 21/50
# 32/32 - 11s - 333ms/step - accuracy: 0.8512 - loss: 0.3728 - mean_io_u: 0.6263 - val_accuracy: 0.7122 - val_loss: 0.8127 - val_mean_io_u: 0.4154
# Epoch 22/50
# 32/32 - 9s - 286ms/step - accuracy: 0.8635 - loss: 0.3415 - mean_io_u: 0.6478 - val_accuracy: 0.7236 - val_loss: 0.8209 - val_mean_io_u: 0.4301
# Epoch 23/50
# 32/32 - 13s - 395ms/step - accuracy: 0.8692 - loss: 0.3264 - mean_io_u: 0.6595 - val_accuracy: 0.7232 - val_loss: 0.8931 - val_mean_io_u: 0.4297
# Epoch 24/50
# 32/32 - 8s - 247ms/step - accuracy: 0.8663 - loss: 0.3343 - mean_io_u: 0.6555 - val_accuracy: 0.7315 - val_loss: 0.8726 - val_mean_io_u: 0.4401
# Epoch 25/50
# 32/32 - 7s - 225ms/step - accuracy: 0.8649 - loss: 0.3378 - mean_io_u: 0.6546 - val_accuracy: 0.7535 - val_loss: 0.7636 - val_mean_io_u: 0.4803
# Epoch 26/50
# 32/32 - 10s - 306ms/step - accuracy: 0.8715 - loss: 0.3215 - mean_io_u: 0.6659 - val_accuracy: 0.7408 - val_loss: 0.8389 - val_mean_io_u: 0.4815
# Epoch 27/50
# 32/32 - 10s - 304ms/step - accuracy: 0.8779 - loss: 0.3028 - mean_io_u: 0.6764 - val_accuracy: 0.7310 - val_loss: 0.9202 - val_mean_io_u: 0.4827
# Epoch 28/50
# 32/32 - 10s - 323ms/step - accuracy: 0.8853 - loss: 0.2827 - mean_io_u: 0.6911 - val_accuracy: 0.7366 - val_loss: 0.9036 - val_mean_io_u: 0.4895
# Epoch 29/50
# 32/32 - 9s - 281ms/step - accuracy: 0.8961 - loss: 0.2545 - mean_io_u: 0.7116 - val_accuracy: 0.7455 - val_loss: 0.8522 - val_mean_io_u: 0.4977
# Epoch 30/50
# 32/32 - 8s - 261ms/step - accuracy: 0.9034 - loss: 0.2357 - mean_io_u: 0.7267 - val_accuracy: 0.7513 - val_loss: 0.8350 - val_mean_io_u: 0.5009
# Epoch 31/50
# 32/32 - 9s - 293ms/step - accuracy: 0.9080 - loss: 0.2236 - mean_io_u: 0.7372 - val_accuracy: 0.7501 - val_loss: 0.9026 - val_mean_io_u: 0.5004
# Epoch 32/50
# 32/32 - 10s - 320ms/step - accuracy: 0.9110 - loss: 0.2160 - mean_io_u: 0.7443 - val_accuracy: 0.7065 - val_loss: 1.4017 - val_mean_io_u: 0.4566
# Epoch 33/50
# 32/32 - 10s - 324ms/step - accuracy: 0.9115 - loss: 0.2152 - mean_io_u: 0.7459 - val_accuracy: 0.6306 - val_loss: 2.5189 - val_mean_io_u: 0.3824
# Epoch 34/50
# 32/32 - 11s - 335ms/step - accuracy: 0.9074 - loss: 0.2266 - mean_io_u: 0.7377 - val_accuracy: 0.6288 - val_loss: 2.4720 - val_mean_io_u: 0.3866
# Epoch 35/50
# 32/32 - 12s - 387ms/step - accuracy: 0.9047 - loss: 0.2336 - mean_io_u: 0.7326 - val_accuracy: 0.7036 - val_loss: 1.2678 - val_mean_io_u: 0.4680
# Epoch 36/50
# 32/32 - 6s - 201ms/step - accuracy: 0.9010 - loss: 0.2462 - mean_io_u: 0.7261 - val_accuracy: 0.7173 - val_loss: 1.1015 - val_mean_io_u: 0.4796
# Epoch 37/50
# 32/32 - 10s - 321ms/step - accuracy: 0.9016 - loss: 0.2418 - mean_io_u: 0.7276 - val_accuracy: 0.7152 - val_loss: 1.3545 - val_mean_io_u: 0.4728
# Epoch 38/50
# 32/32 - 13s - 395ms/step - accuracy: 0.9035 - loss: 0.2359 - mean_io_u: 0.7302 - val_accuracy: 0.6972 - val_loss: 1.3502 - val_mean_io_u: 0.4614
# Epoch 39/50
# 32/32 - 8s - 254ms/step - accuracy: 0.9036 - loss: 0.2364 - mean_io_u: 0.7306 - val_accuracy: 0.7377 - val_loss: 1.0214 - val_mean_io_u: 0.4945
# Epoch 40/50
# 32/32 - 8s - 243ms/step - accuracy: 0.9058 - loss: 0.2305 - mean_io_u: 0.7365 - val_accuracy: 0.7534 - val_loss: 0.9583 - val_mean_io_u: 0.4938
# Epoch 41/50
# 32/32 - 9s - 280ms/step - accuracy: 0.9103 - loss: 0.2181 - mean_io_u: 0.7463 - val_accuracy: 0.7400 - val_loss: 1.0602 - val_mean_io_u: 0.4908
# Epoch 42/50
# 32/32 - 8s - 264ms/step - accuracy: 0.9136 - loss: 0.2103 - mean_io_u: 0.7525 - val_accuracy: 0.7350 - val_loss: 1.1176 - val_mean_io_u: 0.4899
# Epoch 43/50
# 32/32 - 7s - 225ms/step - accuracy: 0.9150 - loss: 0.2072 - mean_io_u: 0.7553 - val_accuracy: 0.7346 - val_loss: 1.1241 - val_mean_io_u: 0.4942
# Epoch 44/50
# 32/32 - 6s - 203ms/step - accuracy: 0.9184 - loss: 0.1987 - mean_io_u: 0.7629 - val_accuracy: 0.6964 - val_loss: 1.5934 - val_mean_io_u: 0.4534
# Epoch 45/50
# 32/32 - 9s - 277ms/step - accuracy: 0.9208 - loss: 0.1925 - mean_io_u: 0.7687 - val_accuracy: 0.7118 - val_loss: 1.4243 - val_mean_io_u: 0.4693
# Epoch 46/50
# 32/32 - 8s - 242ms/step - accuracy: 0.9218 - loss: 0.1900 - mean_io_u: 0.7709 - val_accuracy: 0.7452 - val_loss: 1.1933 - val_mean_io_u: 0.4966
# Epoch 47/50
# 32/32 - 10s - 322ms/step - accuracy: 0.9247 - loss: 0.1816 - mean_io_u: 0.7783 - val_accuracy: 0.7493 - val_loss: 1.1858 - val_mean_io_u: 0.4966
# Epoch 48/50
# 32/32 - 10s - 304ms/step - accuracy: 0.9253 - loss: 0.1805 - mean_io_u: 0.7799 - val_accuracy: 0.7439 - val_loss: 1.1348 - val_mean_io_u: 0.5005
# Epoch 49/50
# 32/32 - 9s - 280ms/step - accuracy: 0.9255 - loss: 0.1805 - mean_io_u: 0.7812 - val_accuracy: 0.7378 - val_loss: 1.1012 - val_mean_io_u: 0.4999
# Epoch 50/50
# 32/32 - 8s - 235ms/step - accuracy: 0.9269 - loss: 0.1766 - mean_io_u: 0.7843 - val_accuracy: 0.7287 - val_loss: 1.1440 - val_mean_io_u: 0.4887

# %%
model.evaluate(valid_dataset, verbose=1)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.7305 - loss: 1.1314 - mean_io_u: 0.4916
# [1.1440237760543823, 0.7287287712097168, 0.4886578619480133]

# %%
val_dataset = get_dataset(
    batch_size, img_size, val_input_img_paths, val_target_img_paths
)
val_preds = model.predict(val_dataset)


def display_mask(i):
    mask = np.argmax(val_preds[i], axis=-1)
    mask = np.expand_dims(mask, axis=-1)
    img = ImageOps.autocontrast(keras.utils.array_to_img(mask))
    display(img)
i = 10
display(Image(filename=val_input_img_paths[i]))
img = ImageOps.autocontrast(load_img(val_target_img_paths[i]))
display(img)
display_mask(i)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step
# <PIL.Image.Image image mode=RGB size=333x500>
# <PIL.Image.Image image mode=L size=160x160>

# %%
from keras import layers, ops
import matplotlib.pyplot as plt
val_dataset = get_dataset(
    200, img_size, val_input_img_paths, val_target_img_paths
)
images, masks = next(iter(val_dataset))
random_idx = keras.random.uniform([], minval=0, maxval=50,seed=50)
for i in range(5):
    test_image = images[i].numpy().astype("float")
    test_mask = masks[i].numpy().astype("float")

    pred_image = ops.expand_dims(test_image, axis=0)
    pred_image = keras.applications.vgg19.preprocess_input(pred_image)
    pred_mask_32s = model.predict(pred_image, verbose=0).astype("float")
    pred_mask_32s = np.argmax(pred_mask_32s, axis=-1)
    pred_mask_32s = pred_mask_32s[0, ...]
    fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15, 8))
    ax[0].set_title("Image")
    ax[0].imshow(test_image / 255.0)

    ax[1].set_title("Image with ground truth overlay")
    ax[1].imshow(test_image / 255.0)
    ax[1].imshow(
        test_mask,
        cmap="gray",
        # alpha=0.6,
    )

    ax[2].set_title("Image with mask overlay")
    ax[2].imshow(test_image / 255.0)
    ax[2].imshow(pred_mask_32s, cmap="gray")



    plt.show()
